# %% [markdown]
# ### Importando librerías

# %%
import tensorflow as tf
from tensorflow.keras import models,layers
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = (256,256)
BATCH_SIZE = 32

# %% [markdown]
# ### Importando imágenes

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "archive\data",
    shuffle=True,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)
# Out:
# Found 4188 files belonging to 4 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Blight', 'Common_Rust', 'Gray_Leaf_Spot', 'Healthy']

# %%
plt.figure(figsize=(10,10))
for image_batch , label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(class_names[label_batch[i]])
        plt.axis('off')

# %% [markdown]
# ### Data Augmentation

# %%
def get_dataset(ds,train_split=0.8,val_split=0.1,test_split=0.1,shuffle=True,shuffle_size=10000):
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size,seed=8)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    
    val_ds = ds.skip(train_size).take(val_size) 
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds,val_ds,test_ds

# %%
train_ds,val_ds,test_ds = get_dataset(dataset)

# %%
print("Length of Training Dataset is",len(train_ds))
print("\nLength of Validation Dataset is",len(val_ds))
print("\nLength of Testing Dataset is",len(test_ds))
# Out:
# Length of Training Dataset is 104
#
# Length of Validation Dataset is 13
#
# Length of Testing Dataset is 14

# %%
# optimizaciones adicionales a los conjuntos de datos de entrenamiento, validación y prueba creados por la función get_dataset()
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
layers.experimental.preprocessing.Resizing(256,256),
layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2),
])

# %% [markdown]
# ### Modelo CNN

# %%
n_classes = 4
input_shape = (BATCH_SIZE,256,256,3)
model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32,(3,3),activation ='relu',input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3),activation ='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3),activation ='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3),activation ='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3),activation ='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(n_classes,activation='softmax'),
    
])
model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (32, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (32, 254, 254, 32)        896
#
#  max_pooling2d (MaxPooling2D  (32, 127, 127, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (32, 125, 125, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (32, 62, 62, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (32, 60, 60, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (32, 30, 30, 64)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (32, 28, 28, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (32, 14, 14, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (32, 12, 12, 64)          36928
#
#  max_pooling2d_4 (MaxPooling  (32, 6, 6, 64)           0
#  2D)
#
#  flatten (Flatten)           (32, 2304)                0
#
#  dense (Dense)               (32, 64)                  147520
#
#  dense_1 (Dense)             (32, 4)                   260
#
# =================================================================
# Total params: 277,956
# Trainable params: 277,956
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
optimizer='adam',
loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
metrics=['accuracy']
)

# %% [markdown]
# ### Fitting

# %%
history = model.fit(
train_ds,
epochs=40,
batch_size=BATCH_SIZE,
verbose=1,
validation_data=val_ds)
# Out:
# Epoch 1/40
# 104/104 [==============================] - 223s 2s/step - loss: 0.9572 - accuracy: 0.5259 - val_loss: 0.8291 - val_accuracy: 0.5938
# Epoch 2/40
# 104/104 [==============================] - 166s 2s/step - loss: 0.8162 - accuracy: 0.6125 - val_loss: 0.7354 - val_accuracy: 0.7476
# Epoch 3/40
# 104/104 [==============================] - 187s 2s/step - loss: 0.5594 - accuracy: 0.7705 - val_loss: 0.4219 - val_accuracy: 0.8413
# Epoch 4/40
# 104/104 [==============================] - 177s 2s/step - loss: 0.4364 - accuracy: 0.8267 - val_loss: 0.3704 - val_accuracy: 0.8341
# Epoch 5/40
# 104/104 [==============================] - 188s 2s/step - loss: 0.3541 - accuracy: 0.8520 - val_loss: 0.3502 - val_accuracy: 0.8630
# Epoch 6/40
# 104/104 [==============================] - 187s 2s/step - loss: 0.3293 - accuracy: 0.8652 - val_loss: 0.3210 - val_accuracy: 0.8726
# Epoch 7/40
# 104/104 [==============================] - 171s 2s/step - loss: 0.3227 - accuracy: 0.8694 - val_loss: 0.4539 - val_accuracy: 0.8389
# Epoch 8/40
# 104/104 [==============================] - 168s 2s/step - loss: 0.3134 - accuracy: 0.8788 - val_loss: 0.3319 - val_accuracy: 0.8846
# Epoch 9/40
# 104/104 [==============================] - 178s 2s/step - loss: 0.2831 - accuracy: 0.8827 - val_loss: 0.3082 - val_accuracy: 0.8798
# Epoch 10/40
# 104/104 [==============================] - 183s 2s/step - loss: 0.2951 - accuracy: 0.8800 - val_loss: 0.3158 - val_accuracy: 0.8918
# Epoch 11/40
# 104/104 [==============================] - 169s 2s/step - loss: 0.2762 - accuracy: 0.8917 - val_loss: 0.2649 - val_accuracy: 0.8918
# Epoch 12/40
# 104/104 [==============================] - 176s 2s/step - loss: 0.2794 - accuracy: 0.8863 - val_loss: 0.3255 - val_accuracy: 0.8846
# Epoch 13/40
# 104/104 [==============================] - 164s 2s/step - loss: 0.2638 - accuracy: 0.8923 - val_loss: 0.2807 - val_accuracy: 0.8942
# Epoch 14/40
# 104/104 [==============================] - 167s 2s/step - loss: 0.2481 - accuracy: 0.9001 - val_loss: 0.3089 - val_accuracy: 0.8966
# Epoch 15/40
# 104/104 [==============================] - 169s 2s/step - loss: 0.2519 - accuracy: 0.9028 - val_loss: 0.2489 - val_accuracy: 0.8894
# Epoch 16/40
# 104/104 [==============================] - 199s 2s/step - loss: 0.2821 - accuracy: 0.8878 - val_loss: 0.2849 - val_accuracy: 0.8966
# Epoch 17/40
# 104/104 [==============================] - 180s 2s/step - loss: 0.2584 - accuracy: 0.8959 - val_loss: 0.2727 - val_accuracy: 0.8894
# Epoch 18/40
# 104/104 [==============================] - 136s 1s/step - loss: 0.2461 - accuracy: 0.9037 - val_loss: 0.2986 - val_accuracy: 0.8894
# Epoch 19/40
# 104/104 [==============================] - 136s 1s/step - loss: 0.2327 - accuracy: 0.9103 - val_loss: 0.3577 - val_accuracy: 0.8942
# Epoch 20/40
# 104/104 [==============================] - 137s 1s/step - loss: 0.2440 - accuracy: 0.9052 - val_loss: 0.3184 - val_accuracy: 0.9062
# Epoch 21/40
# 104/104 [==============================] - 137s 1s/step - loss: 0.2319 - accuracy: 0.9079 - val_loss: 0.2099 - val_accuracy: 0.9111
# Epoch 22/40
# 104/104 [==============================] - 241s 2s/step - loss: 0.2284 - accuracy: 0.9146 - val_loss: 0.2528 - val_accuracy: 0.8966
# Epoch 23/40
# 104/104 [==============================] - 164s 2s/step - loss: 0.2191 - accuracy: 0.9128 - val_loss: 0.2142 - val_accuracy: 0.9159
# Epoch 24/40
# 104/104 [==============================] - 169s 2s/step - loss: 0.2139 - accuracy: 0.9176 - val_loss: 0.2442 - val_accuracy: 0.9111
# Epoch 25/40
# 104/104 [==============================] - 162s 2s/step - loss: 0.2066 - accuracy: 0.9224 - val_loss: 0.2147 - val_accuracy: 0.9159
# Epoch 26/40
# 104/104 [==============================] - 135s 1s/step - loss: 0.2154 - accuracy: 0.9170 - val_loss: 0.2005 - val_accuracy: 0.9087
# Epoch 27/40
# 104/104 [==============================] - 135s 1s/step - loss: 0.2056 - accuracy: 0.9197 - val_loss: 0.2224 - val_accuracy: 0.9111
# Epoch 28/40
# 104/104 [==============================] - 167s 2s/step - loss: 0.1927 - accuracy: 0.9242 - val_loss: 0.1935 - val_accuracy: 0.9279
# Epoch 29/40
# 104/104 [==============================] - 162s 2s/step - loss: 0.2089 - accuracy: 0.9200 - val_loss: 0.1884 - val_accuracy: 0.9111
# Epoch 30/40
# 104/104 [==============================] - 161s 2s/step - loss: 0.1838 - accuracy: 0.9266 - val_loss: 0.2096 - val_accuracy: 0.9087
# Epoch 31/40
# 104/104 [==============================] - 159s 2s/step - loss: 0.1851 - accuracy: 0.9230 - val_loss: 0.1997 - val_accuracy: 0.9111
# Epoch 32/40
# 104/104 [==============================] - 131s 1s/step - loss: 0.1716 - accuracy: 0.9335 - val_loss: 0.2042 - val_accuracy: 0.9279
# Epoch 33/40
# 104/104 [==============================] - 130s 1s/step - loss: 0.1901 - accuracy: 0.9233 - val_loss: 0.1632 - val_accuracy: 0.9303
# Epoch 34/40
# 104/104 [==============================] - 130s 1s/step - loss: 0.1869 - accuracy: 0.9233 - val_loss: 0.1877 - val_accuracy: 0.9255
# Epoch 35/40
# 104/104 [==============================] - 130s 1s/step - loss: 0.1692 - accuracy: 0.9347 - val_loss: 0.2084 - val_accuracy: 0.9159
# Epoch 36/40
# 104/104 [==============================] - 2801s 27s/step - loss: 0.1627 - accuracy: 0.9365 - val_loss: 0.1923 - val_accuracy: 0.9183
# Epoch 37/40
# 104/104 [==============================] - 152s 1s/step - loss: 0.1789 - accuracy: 0.9326 - val_loss: 0.1712 - val_accuracy: 0.9423
# Epoch 38/40
# 104/104 [==============================] - 151s 1s/step - loss: 0.1701 - accuracy: 0.9323 - val_loss: 0.2173 - val_accuracy: 0.9135
# Epoch 39/40
# 104/104 [==============================] - 186s 2s/step - loss: 0.1797 - accuracy: 0.9326 - val_loss: 0.2196 - val_accuracy: 0.9159
# Epoch 40/40
# 104/104 [==============================] - 199s 2s/step - loss: 0.1727 - accuracy: 0.9377 - val_loss: 0.1933 - val_accuracy: 0.9279

# %%
scores = model.evaluate(test_ds)
# Out:
# 14/14 [==============================] - 16s 322ms/step - loss: 0.1806 - accuracy: 0.9353

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 40, 'steps': 104}

# %%
his_data = pd.DataFrame(history.history)
plt.figure(figsize=(20,5))

plt.subplot(1,2,1)
plt.plot(his_data.loss, label="Training loss")
plt.plot(his_data.val_loss, label="Validation loss")
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.title("Losses")
plt.grid()
plt.legend()

plt.subplot(1,2,2)
plt.plot(his_data.accuracy, label="Training accuracy")
plt.plot(his_data.val_accuracy, label="Validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy")
plt.grid()
plt.legend()

# %% [markdown]
# ### Prediction

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    print("First Image to Predict :")
    plt.imshow(first_image)
    print("\nActual label:",class_names[first_label])
    batch_prediction = model. predict (images_batch) 
    print("\nPredicted label" ,class_names[np.argmax(batch_prediction[0])])
# Out:
# First Image to Predict :
#
# Actual label: Healthy
# 1/1 [==============================] - 0s 492ms/step
#
# Predicted label Healthy

# %%
def predict(model,img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0) # Create a batch
    predictions = model.predict (img_array)
    predicted_class = class_names[np.argmax(predictions[0])]
#     confidence = round(np.max(predictions[0]),2)
    confidence = round(100*(np.max(predictions[0])),2)

    return predicted_class, confidence

# %%
plt.figure(figsize=(15,15))
for images,labels in test_ds.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class , confidence = predict(model,images[i].numpy())
        actual_class = class_names[labels[i]]
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class},\n Confidence Score: {confidence}%")
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step

# %%
model.save('Proyecto final/model_1')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Proyecto final/model_1\assets
# INFO:tensorflow:Assets written to: Proyecto final/model_1\assets
